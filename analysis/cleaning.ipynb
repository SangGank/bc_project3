# %%
import pandas as pd

# %%
for i in range(4):
    train_0 = pd.read_csv(f'../dev/dev_{i}.csv')
    train_0[train_0.target != train_0.pred_target].to_csv(f'../cleaning/{i}.csv',index=False)
    print(len(train_0[train_0.target != train_0.pred_target]))
# Out:
# 261
# 281
# 261
# 296

# %%
df = pd.DataFrame()
for i in range(4):
    train=pd.read_csv(f'../cleaning/{i}.csv')
    df=pd.concat([df,train],axis=False)
df.reset_index().drop(columns=['index'])
# Out:
#                        ID                               text  target
# 0     ynat-v1_train_00024   이뤄 뢰구긴 관광개 길보니 한구긔 이배…격차 계소 콱때되나       1  \
# 1     ynat-v1_train_00064  나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승       0
# 2     ynat-v1_train_00076       눈물 쏟은 문경은 선수 때 우승하고도 안 울었는데…       0
# 3     ynat-v1_train_00084         빅텍 방위사업청에 60억원 규모 전자전장비 공급       0
# 4     ynat-v1_train_00128       3번 연기한 충북 기능경기대회 열려…일부 경기 차질       2
# ...                   ...                                ...     ...
# 1094  ynat-v1_train_06811                   이 총니 세종서 궁무회의 주재       6
# 1095  ynat-v1_train_06851    트럼프 우크라 대통령 통화 며칠전 원조중단 지시…탄핵론↑       6
# 1096  ynat-v1_train_06879     경북지사·포항시장 국무총리에 실질적 지진피해 구제 요청       6
# 1097  ynat-v1_train_06939   러시아 어린이 오디션 프로그램 우승자 투표 조작으로 떠들썩       0
# 1098  ynat-v1_train_06955      1608년 지도가 말하는 사실 남중국해는 상인의 바다       2
#
#                                                     url                  date
# ...

# %%
df.reset_index().drop(columns=['index']).to_csv('totalWrong.csv',index=False)
