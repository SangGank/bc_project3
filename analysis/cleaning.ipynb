# %%
import pandas as pd
import evaluate

# %%
for i in range(4):
    train_0 = pd.read_csv(f'../dev/dev_{i}.csv')
    train_0[train_0.target != train_0.pred_target].to_csv(f'../cleaning/{i}.csv',index=False)
    print(len(train_0[train_0.target != train_0.pred_target]))
# Out:
# 261
# 281
# 261
# 296

# %%
df = pd.DataFrame()
for i in range(4):
    train=pd.read_csv(f'../cleaning/{i}.csv')
    df=pd.concat([df,train],axis=False)
df.reset_index().drop(columns=['index'])
# Out:
#                        ID                               text  target
# 0     ynat-v1_train_00024   이뤄 뢰구긴 관광개 길보니 한구긔 이배…격차 계소 콱때되나       1  \
# 1     ynat-v1_train_00064  나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승       0
# 2     ynat-v1_train_00076       눈물 쏟은 문경은 선수 때 우승하고도 안 울었는데…       0
# 3     ynat-v1_train_00084         빅텍 방위사업청에 60억원 규모 전자전장비 공급       0
# 4     ynat-v1_train_00128       3번 연기한 충북 기능경기대회 열려…일부 경기 차질       2
# ...                   ...                                ...     ...
# 1094  ynat-v1_train_06811                   이 총니 세종서 궁무회의 주재       6
# 1095  ynat-v1_train_06851    트럼프 우크라 대통령 통화 며칠전 원조중단 지시…탄핵론↑       6
# 1096  ynat-v1_train_06879     경북지사·포항시장 국무총리에 실질적 지진피해 구제 요청       6
# 1097  ynat-v1_train_06939   러시아 어린이 오디션 프로그램 우승자 투표 조작으로 떠들썩       0
# 1098  ynat-v1_train_06955      1608년 지도가 말하는 사실 남중국해는 상인의 바다       2
#
#                                                     url                  date
# ...

# %%
df.reset_index().drop(columns=['index']).to_csv('totalWrong.csv',index=False)

# %%
for i in range(4):
    train_0 = pd.read_csv(f'../dev/dev_p2g_{i}.csv')
    train_0[train_0.target != train_0.pred_target].to_csv(f'../cleaning/p2g_{i}.csv',index=False)
    print(len(train_0[train_0.target != train_0.pred_target]))
# Out:
# 259
# 279
# 260
# 286

# %%
for i in range(4):
    train_0 = pd.read_csv(f'../dev/dev_Jiyoung_{i}.csv')
    train_0[train_0.target != train_0.pred_target].to_csv(f'../cleaning/Jiyoung_{i}.csv',index=False)
    print(len(train_0[train_0.target != train_0.pred_target]))
# Out:
# 255
# 271
# 249
# 269

# %%
df = pd.DataFrame()
for i in range(4):
    train=pd.read_csv(f'../cleaning/Jiyoung_{i}.csv')
    df=pd.concat([df,train],axis=False)
df.reset_index().drop(columns=['index'])
# Out:
#                        ID                                    text  target
# 0     ynat-v1_train_00024        1월 외국인 관광객 일본이 한국의 2배…격차 계속 확대되나       1  \
# 1     ynat-v1_train_00064       나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승       0
# 2     ynat-v1_train_00076            눈물 쏟은 문경은 선수 때 우승하고도 안 울었는데…       0
# 3     ynat-v1_train_00084              빅텍 방위사업청에 60억원 규모 전자전장비 공급       0
# 4     ynat-v1_train_00128            3번 연기한 충북 기능경기대회 열려…일부 경기 차질       2
# ...                   ...                                     ...     ...
# 1039  ynat-v1_train_06783  류허 中부총리 방미…10∼11일 워싱턴서 미중 고위급 무역협상종합2보       4
# 1040  ynat-v1_train_06851         트럼프 우크라 대통령 통화 며칠전 원조중단 지시…탄핵론↑       6
# 1041  ynat-v1_train_06879          경북지사·포항시장 국무총리에 실질적 지진피해 구제 요청       6
# 1042  ynat-v1_train_06939        러시아 어린이 오디션 프로그램 우승자 투표 조작으로 떠들썩       0
# 1043  ynat-v1_train_06955           1608년 지도가 말하는 사실 남중국해는 상인의 바다       2
#
#                                                     url                  date
# ...

# %%
df.reset_index().drop(columns=['index']).to_csv('totalJiyoung.csv',index=False)

# %%
df = pd.DataFrame()
for i in range(4):
    train=pd.read_csv(f'../cleaning/p2g_{i}.csv')
    df=pd.concat([df,train],axis=False)
df.reset_index().drop(columns=['index'])
# Out:
#                        ID                               text  target
# 0     ynat-v1_train_00024   이뤄 뢰구긴 관광개 길보니 한구긔 이배…격차 계소 콱때되나       1  \
# 1     ynat-v1_train_00064  나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승       0
# 2     ynat-v1_train_00076       눈물 쏟은 문경은 선수 때 우승하고도 안 울었는데…       0
# 3     ynat-v1_train_00084         빅텍 방위사업청에 60억원 규모 전자전장비 공급       0
# 4     ynat-v1_train_00128       3번 연기한 충북 기능경기대회 열려…일부 경기 차질       2
# ...                   ...                                ...     ...
# 1079  ynat-v1_train_06811                   이 총니 세종서 궁무회의 주재       6
# 1080  ynat-v1_train_06851    트럼프 우크라 대통령 통화 며칠전 원조중단 지시…탄핵론↑       6
# 1081  ynat-v1_train_06879     경북지사·포항시장 국무총리에 실질적 지진피해 구제 요청       6
# 1082  ynat-v1_train_06939   러시아 어린이 오디션 프로그램 우승자 투표 조작으로 떠들썩       0
# 1083  ynat-v1_train_06955      1608년 지도가 말하는 사실 남중국해는 상인의 바다       2
#
#                                                     url                  date
# ...

# %%
df.reset_index().drop(columns=['index']).to_csv('totalWrong_p2g.csv',index=False)

# %%
train1 = pd.read_csv('../totalWrong.csv')
train2 = pd.read_csv('../totalWrong_p2g.csv')

# %%
_train = pd.merge(train1.loc[:,:'target'],train2.loc[:,:'target'], how='outer',on='ID')
_train
# Out:
#                        ID                             text_x  target_x
# 0     ynat-v1_train_00024   이뤄 뢰구긴 관광개 길보니 한구긔 이배…격차 계소 콱때되나       1.0  \
# 1     ynat-v1_train_00064  나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승       0.0
# 2     ynat-v1_train_00076       눈물 쏟은 문경은 선수 때 우승하고도 안 울었는데…       0.0
# 3     ynat-v1_train_00084         빅텍 방위사업청에 60억원 규모 전자전장비 공급       0.0
# 4     ynat-v1_train_00128       3번 연기한 충북 기능경기대회 열려…일부 경기 차질       2.0
# ...                   ...                                ...       ...
# 1153  ynat-v1_train_05551                                NaN       NaN
# 1154  ynat-v1_train_05783                                NaN       NaN
# 1155  ynat-v1_train_06327                                NaN       NaN
# 1156  ynat-v1_train_06759                                NaN       NaN
# 1157  ynat-v1_train_06791                                NaN       NaN
#
#                                  text_y  target_y
# 0      이뤄 뢰구긴 관광개 길보니 한구긔 이배…격차 계소 콱때되나       1.0
# ...

# %%
_train[_train.text_x.isna()].to_csv('../not1.csv',index=False)
_train[_train.text_x.isna()]
# Out:
#                        ID text_x  target_x
# 1099  ynat-v1_train_01376    NaN       NaN  \
# 1100  ynat-v1_train_01544    NaN       NaN
# 1101  ynat-v1_train_02204    NaN       NaN
# 1102  ynat-v1_train_03332    NaN       NaN
# 1103  ynat-v1_train_03340    NaN       NaN
# 1104  ynat-v1_train_03552    NaN       NaN
# 1105  ynat-v1_train_03744    NaN       NaN
# 1106  ynat-v1_train_03772    NaN       NaN
# 1107  ynat-v1_train_03984    NaN       NaN
# 1108  ynat-v1_train_04332    NaN       NaN
# 1109  ynat-v1_train_04352    NaN       NaN
# 1110  ynat-v1_train_05316    NaN       NaN
# 1111  ynat-v1_train_05444    NaN       NaN
# 1112  ynat-v1_train_05944    NaN       NaN
# 1113  ynat-v1_train_06096    NaN       NaN
# 1114  ynat-v1_train_01101    NaN       NaN
# 1115  ynat-v1_train_01525    NaN       NaN
# 1116  ynat-v1_train_02241    NaN       NaN
# 1117  ynat-v1_train_02369    NaN       NaN
# 1118  ynat-v1_train_02397    NaN       NaN
# 1119  ynat-v1_train_02429    NaN       NaN
# ...

# %%
len(_train[_train.text_x.isna()])
# Out:
# 59

# %%
_train[_train.text_y.isna()].to_csv('../not2.csv')

# %%
_train[~(_train.text_y.isna()) & ~(_train.text_x.isna())]
# Out:
#                        ID                             text_x  target_x
# 0     ynat-v1_train_00024   이뤄 뢰구긴 관광개 길보니 한구긔 이배…격차 계소 콱때되나       1.0  \
# 1     ynat-v1_train_00064  나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승       0.0
# 2     ynat-v1_train_00076       눈물 쏟은 문경은 선수 때 우승하고도 안 울었는데…       0.0
# 3     ynat-v1_train_00084         빅텍 방위사업청에 60억원 규모 전자전장비 공급       0.0
# 4     ynat-v1_train_00128       3번 연기한 충북 기능경기대회 열려…일부 경기 차질       2.0
# ...                   ...                                ...       ...
# 1094  ynat-v1_train_06811                   이 총니 세종서 궁무회의 주재       6.0
# 1095  ynat-v1_train_06851    트럼프 우크라 대통령 통화 며칠전 원조중단 지시…탄핵론↑       6.0
# 1096  ynat-v1_train_06879     경북지사·포항시장 국무총리에 실질적 지진피해 구제 요청       6.0
# 1097  ynat-v1_train_06939   러시아 어린이 오디션 프로그램 우승자 투표 조작으로 떠들썩       0.0
# 1098  ynat-v1_train_06955      1608년 지도가 말하는 사실 남중국해는 상인의 바다       2.0
#
#                                  text_y  target_y
# 0      이뤄 뢰구긴 관광개 길보니 한구긔 이배…격차 계소 콱때되나       1.0
# ...

# %%
_train[~(_train.text_y.isna()) & ~(_train.text_x.isna())].to_csv('../all.csv')

# %%
wrongp2g= pd.read_csv('../totalWrong_p2g제거.csv')

# %%
merg = pd.merge(wrongp2g.loc[:,:'target'],_train.loc[: ,['ID','text_y','target_y']], on='ID',how='outer' )
merg
# Out:
#                        ID                               text  target
# 0     ynat-v1_train_00024   1월 외국인 관광객 일본이 한국의 2배…격차 계속 확대되나     1.0  \
# 1     ynat-v1_train_00064  나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승     0.0
# 2     ynat-v1_train_00076       눈물 쏟은 문경은 선수 때 우승하고도 안 울었는데…     0.0
# 3     ynat-v1_train_00084         빅텍 방위사업청에 60억원 규모 전자전장비 공급     0.0
# 4     ynat-v1_train_00128       3번 연기한 충북 기능경기대회 열려…일부 경기 차질     2.0
# ...                   ...                                ...     ...
# 1153  ynat-v1_train_05551                                NaN     NaN
# 1154  ynat-v1_train_05783                                NaN     NaN
# 1155  ynat-v1_train_06327                                NaN     NaN
# 1156  ynat-v1_train_06759                                NaN     NaN
# 1157  ynat-v1_train_06791                                NaN     NaN
#
#                                  text_y  target_y
# 0      이뤄 뢰구긴 관광개 길보니 한구긔 이배…격차 계소 콱때되나       1.0
# ...

# %%
merg.to_csv('./merg.csv',index=False)

# %%
x= pd.read_csv('./merg.csv')
x.to_csv('./merg.csv',index=False, encoding='cp949')

# %%
x.target.value_counts().reindex(range(7)).plot(kind='bar')
# Out:
# <Axes: xlabel='target'>

# %%
x.pred_target.value_counts().reindex(range(7)).plot(kind='bar')
# Out:
# <Axes: xlabel='pred_target'>

# %%
merg[(merg.text == merg.text_y)]
# Out:
#                        ID                               text  target
# 1     ynat-v1_train_00064  나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승     0.0  \
# 2     ynat-v1_train_00076       눈물 쏟은 문경은 선수 때 우승하고도 안 울었는데…     0.0
# 3     ynat-v1_train_00084         빅텍 방위사업청에 60억원 규모 전자전장비 공급     0.0
# 4     ynat-v1_train_00128       3번 연기한 충북 기능경기대회 열려…일부 경기 차질     2.0
# 5     ynat-v1_train_00140        미생 日정부 주최 미디어예술상 우수상…구성 뛰어나     3.0
# ...                   ...                                ...     ...
# 1094  ynat-v1_train_06811                   이 총니 세종서 궁무회의 주재     6.0
# 1095  ynat-v1_train_06851    트럼프 우크라 대통령 통화 며칠전 원조중단 지시…탄핵론↑     6.0
# 1096  ynat-v1_train_06879     경북지사·포항시장 국무총리에 실질적 지진피해 구제 요청     6.0
# 1097  ynat-v1_train_06939   러시아 어린이 오디션 프로그램 우승자 투표 조작으로 떠들썩     0.0
# 1098  ynat-v1_train_06955      1608년 지도가 말하는 사실 남중국해는 상인의 바다     2.0
#
#                                  text_y  target_y
# 1     나경복 개인 첫 트리플크라운…우리카드 구단 최다 타이 5연승       0.0
# ...

# %%
len(merg[(merg.text != merg.text_y) & (merg.text.isna())])
# Out:
# 59

# %%
vaid= pd.read_csv('../dev/dev_g2p_change_0.csv')

# %%
f1 = evaluate.load('f1')
f1.compute(predictions= vaid.pred_target, references=vaid.target, average='macro')
# Out:
# {'f1': 0.856178616713504}

# %%
for i in range(4):
    vaid= pd.read_csv(f'../dev/dev_p2g_{i}.csv')
    f1 = evaluate.load('f1')
    score = f1.compute(predictions= vaid.pred_target, references=vaid.target, average='macro')
    print(score)
# Out:
# {'f1': 0.8502599798258027}
# {'f1': 0.8395789625891386}
# {'f1': 0.8477619275926578}
# {'f1': 0.835719293978541}

# %%
for i in range(4):
    vaid= pd.read_csv(f'../dev/dev_g2p_change_{i}.csv')
    f1 = evaluate.load('f1')
    score = f1.compute(predictions= vaid.pred_target, references=vaid.target, average='macro')
    print(score)
# Out:
# {'f1': 0.856178616713504}
# {'f1': 0.8481772781222163}
# {'f1': 0.8545209914593919}
# {'f1': 0.8427545078217802}
