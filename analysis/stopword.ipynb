# %%
import pandas as pd
from collections import Counter

# %%
train = pd.read_csv('../data/train/Total_train.csv')

# %%
li=[]
for i in train.text:
    li+=list(i.split(' '))
print(li[:10])
# Out:
# ['개포2단지', '분양', '앞두고', '개포지구', '재건축', '불붙어', '삼성전자', 'KBIS', '2018서', '셰프컬렉션']

# %%
count = Counter(li)
count.most_common
# Out:
# <bound method Counter.most_common of Counter({'첫': 138, '게시판': 132, '등': 116, '출시': 115, '北': 105, '신간': 101, '감독': 94, '美': 91, '대통령': 88, 'KT': 85, '朴대통령': 79, '5G': 73, '개최': 70, '개발': 67, '한국': 66, '트럼프': 66, '것': 62, '이란': 62, '만에': 57, '문': 55, '그래픽': 54, '올해': 54, '국내': 54, '월드컵': 52, '전': 51, '더': 51, '中': 51, '중': 49, '지원': 48, '미국': 47, '새': 46, '또': 46, '삼성': 46, '네이버': 46, '작년': 45, 'SKT': 44, '스마트폰': 44, '정부': 44, '공개': 44, '靑': 42, '내년': 41, 'LG': 40, '1위': 40, '추진': 39, '최고': 39, '가능성': 39, '전국': 38, '류현진': 38, '여행': 38, '김정은': 37, '특징주': 37, 'AI': 37, '중국': 36, '서울': 36, '영업익': 35, '프로농구': 35, '서비스': 35, '다시': 35, '돌파': 35, '주말': 35, '연속': 35, 'vs': 34, '2018': 34, '...': 34, '터키': 34, '증가': 34, '기술': 33, '북한': 33, '최대': 33, '총리': 32, '올림픽': 32, '속': 31, '개막': 31, 'N': 31, '안': 30, '듯': 30, '꺾고': 30, '코스피': 30, '아파트': 30, '선정': 29, 'MLB': 29, '영상': 29, '손흥민': 29, '삼성전자': 28, '시즌': 28, '규모': 28, '1분기': 28, '내': 28, '한': 28, '위한': 28, '장관': 28, 'SK텔레콤': 27, '세계': 27, '내
# ...
